# %% [markdown]
# ejercicio_1:

# %%
Tierra = 149597870
Júpiter = 778547200
diferencia_en_km = 149597870 - 778547200
print(abs(diferencia_en_km))
diferencia_en_millas = 628949330 * 0.621
print(diferencia_en_millas)
# Out:
# 628949330
# 390577533.93

# %% [markdown]
# ejercicio_2:

# %%
mercurio = input(57900000)
venus = input(108200000)

# %%
mercurio = int(mercurio)
venus = int(venus)

# %%
distancia_km = 108200000 - 57900000 
print(distancia_km)
distancia_millas = 50300000 * 0.621
print(abs(distancia_millas))
# Out:
# 50300000
# 31236300.0
