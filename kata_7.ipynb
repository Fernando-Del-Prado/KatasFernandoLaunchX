# %%
new_planets = ''
planets = []

# %%
while new_planets.lower() != 'done':
    if new_planets:
        planets.append(new_planets)
        new_planets = input('ingresa un planeta o escriba done cuando termine')

# %%
for planet in planets:
    print(planet)
