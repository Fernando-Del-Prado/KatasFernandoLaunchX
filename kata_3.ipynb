# %%
asteroide = 49 
if asteroide > 25:
    print("¡ALERTA! ¡ALERTA! velocidad del asteroide mayor a 25kms")
else:
    print("¡buen dia!")
# Out:
# ¡ALERTA! ¡ALERTA! velocidad del asteroide mayor a 25kms

# %%
asteroide = 19
if asteroide > 20:
    print("¡miren el cielo!")
elif asteroide == 20:
    print("¡miren el cielo!")
else:
     print("¡no hay nada que ver!")
# Out:
# ¡no hay nada que ver!

# %%
velocidad_del_asteroide = 26
tamaño_del_asteroide = 30
if velocidad_del_asteroide > 20 and tamaño_del_asteroide > 25:
    print("¡ALERTA! asteroide peligroso en camamino hacia la tierra")
elif tamaño_del_asteroide < 25: 
    print("¡todo en orden!")
elif velocidad_del_asteroide >= 20:
    print("¡miren el cielo hay un rayo de luz a la vista!")
else:
    print("¡cielo despejado!")
# Out:
# ¡ALERTA! asteroide peligroso en camamino hacia la tierra
